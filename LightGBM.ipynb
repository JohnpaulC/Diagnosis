# %%
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import train_test_split

dataset = np.load('data/Nearest_neighbor.npy')
X = dataset[:, :-1]
y = dataset[-1]
x_train, x_test, y_train, y_test = train_test_split(
    dataset[:, :-1], dataset[:, -1], random_state=1)

train_data = lgb.Dataset(x_train, label=y_train)
test_data = lgb.Dataset(x_test, label=y_test)

param = {'num_leaves': 31, 'objective': 'binary'}
param['metric'] = ['auc', 'binary_logloss']

num_round = 3000
bst = lgb.train(param, train_data, num_round, valid_sets=[test_data])
# Out:
# [1]	valid_0's auc: 0.999082	valid_0's binary_logloss: 0.5541
# [2]	valid_0's auc: 0.99923	valid_0's binary_logloss: 0.479789
# [3]	valid_0's auc: 0.999258	valid_0's binary_logloss: 0.418965
# [4]	valid_0's auc: 0.99931	valid_0's binary_logloss: 0.368131
# [5]	valid_0's auc: 0.999294	valid_0's binary_logloss: 0.325124
# [6]	valid_0's auc: 0.999341	valid_0's binary_logloss: 0.288314
# [7]	valid_0's auc: 0.999305	valid_0's binary_logloss: 0.256575
# [8]	valid_0's auc: 0.999308	valid_0's binary_logloss: 0.228859
# [9]	valid_0's auc: 0.999256	valid_0's binary_logloss: 0.204595
# [10]	valid_0's auc: 0.999571	valid_0's binary_logloss: 0.183163
# [11]	valid_0's auc: 0.999935	valid_0's binary_logloss: 0.164223
# [12]	valid_0's auc: 0.999936	valid_0's binary_logloss: 0.147363
# [13]	valid_0's auc: 0.99994	valid_0's binary_logloss: 0.132542
# [14]	valid_0's auc: 0.99998	valid_0's binary_logloss: 0.119262
# [15]	valid_0's auc: 0.999922	valid_0's binary_logloss: 0.107479
# [16]	valid_0's auc: 0.999927	valid_0's binary_logloss: 0.0969185
# [17]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0875325
# [18]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0791342
# [19]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0715164
# [20]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0646923
# [21]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.058665
# [22]	valid_0's auc: 0.999988	valid_0's binary_logloss: 0.0530941
# [23]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.0480342
# [24]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.0435049
# [25]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.0393799
# [26]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.035665
# [27]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.0323551
# [28]	valid_0's auc: 0.999994	valid_0's binary_logloss: 0.0292847
# [29]	valid_0's auc: 0.999994	valid_0's binary_logloss: 0.0265151
# [30]	valid_0's auc: 0.999995	valid_0's binary_logloss: 0.0240202
# [31]	valid_0's auc: 0.999996	valid_0's binary_logloss: 0.021754
# [32]	valid_0's auc: 0.999998	valid_0's binary_logloss: 0.0197071
# [33]	valid_0's auc: 0.999999	valid_0's binary_logloss: 0.0178459
# [34]	valid_0's auc: 0.999999	valid_0's binary_logloss: 0.0161782
# [35]	valid_0's auc: 0.999999	valid_0's binary_logloss: 0.0146585
# [36]	valid_0's auc: 0.999999	valid_0's binary_logloss: 0.0132873
# [37]	valid_0's auc: 0.999999	valid_0's binary_logloss: 0.0120489
# [38]	valid_0's auc: 1	valid_0's binary_logloss: 0.0109351
# [39]	valid_0's auc: 1	valid_0's binary_logloss: 0.00992584
# [40]	valid_0's auc: 1	valid_0's binary_logloss: 0.00900785
# [41]	valid_0's auc: 1	valid_0's binary_logloss: 0.00818835
# [42]	valid_0's auc: 1	valid_0's binary_logloss: 0.00744184
# [43]	valid_0's auc: 1	valid_0's binary_logloss: 0.00676632
# [44]	valid_0's auc: 1	valid_0's binary_logloss: 0.00615467
# [45]	valid_0's auc: 1	valid_0's binary_logloss: 0.00560243
# [46]	valid_0's auc: 1	valid_0's binary_logloss: 0.00509952
# [47]	valid_0's auc: 1	valid_0's binary_logloss: 0.00464798
# [48]	valid_0's auc: 1	valid_0's binary_logloss: 0.00423781
# [49]	valid_0's auc: 1	valid_0's binary_logloss: 0.00387382
# [50]	valid_0's auc: 1	valid_0's binary_logloss: 0.0035417
# [51]	valid_0's auc: 1	valid_0's binary_logloss: 0.00323165
# [52]	valid_0's auc: 1	valid_0's binary_logloss: 0.00296575
# [53]	valid_0's auc: 1	valid_0's binary_logloss: 0.00272021
# [54]	valid_0's auc: 1	valid_0's binary_logloss: 0.00249065
# [55]	valid_0's auc: 1	valid_0's binary_logloss: 0.00228619
# [56]	valid_0's auc: 1	valid_0's binary_logloss: 0.00209998
# [57]	valid_0's auc: 1	valid_0's binary_logloss: 0.00193604
# [58]	valid_0's auc: 1	valid_0's binary_logloss: 0.00178655
# [59]	valid_0's auc: 1	valid_0's binary_logloss: 0.0016509
# [60]	valid_0's auc: 1	valid_0's binary_logloss: 0.00153267
# [61]	valid_0's auc: 1	valid_0's binary_logloss: 0.00142034
# [62]	valid_0's auc: 1	valid_0's binary_logloss: 0.00132017
# [63]	valid_0's auc: 1	valid_0's binary_logloss: 0.00123049
# [64]	valid_0's auc: 1	valid_0's binary_logloss: 0.0011496
# [65]	valid_0's auc: 1	valid_0's binary_logloss: 0.0010763
# [66]	valid_0's auc: 1	valid_0's binary_logloss: 0.00101271
# [67]	valid_0's auc: 1	valid_0's binary_logloss: 0.000951297
# [68]	valid_0's auc: 1	valid_0's binary_logloss: 0.000896738
# [69]	valid_0's auc: 1	valid_0's binary_logloss: 0.000846209
# [70]	valid_0's auc: 1	valid_0's binary_logloss: 0.000804704
# [71]	valid_0's auc: 1	valid_0's binary_logloss: 0.000767071
# [72]	valid_0's auc: 1	valid_0's binary_logloss: 0.000726248
# [73]	valid_0's auc: 1	valid_0's binary_logloss: 0.000694038
# [74]	valid_0's auc: 1	valid_0's binary_logloss: 0.000671724
# [75]	valid_0's auc: 1	valid_0's binary_logloss: 0.000641866
# [76]	valid_0's auc: 1	valid_0's binary_logloss: 0.000617716
# [77]	valid_0's auc: 1	valid_0's binary_logloss: 0.000597716
# [78]	valid_0's auc: 1	valid_0's binary_logloss: 0.000578875
# [79]	valid_0's auc: 1	valid_0's binary_logloss: 0.00055466
# [80]	valid_0's auc: 1	valid_0's binary_logloss: 0.000538243
# [81]	valid_0's auc: 1	valid_0's binary_logloss: 0.000522177
# [82]	valid_0's auc: 1	valid_0's binary_logloss: 0.000509857
# [83]	valid_0's auc: 1	valid_0's binary_logloss: 0.000499237
# [84]	valid_0's auc: 1	valid_0's binary_logloss: 0.000487681
# [85]	valid_0's auc: 1	valid_0's binary_logloss: 0.000476678
# [86]	valid_0's auc: 1	valid_0's binary_logloss: 0.000468338
# [87]	valid_0's auc: 1	valid_0's binary_logloss: 0.000458824
# [88]	valid_0's auc: 1	valid_0's binary_logloss: 0.000451722
# [89]	valid_0's auc: 1	valid_0's binary_logloss: 0.000444658
# [90]	valid_0's auc: 1	valid_0's binary_logloss: 0.000444548
# [91]	valid_0's auc: 1	valid_0's binary_logloss: 0.000436617
# [92]	valid_0's auc: 1	valid_0's binary_logloss: 0.000436039
# [93]	valid_0's auc: 1	valid_0's binary_logloss: 0.000433831
# [94]	valid_0's auc: 1	valid_0's binary_logloss: 0.000426954
# [95]	valid_0's auc: 1	valid_0's binary_logloss: 0.000419942
# [96]	valid_0's auc: 1	valid_0's binary_logloss: 0.000414341
# [97]	valid_0's auc: 1	valid_0's binary_logloss: 0.000414421
# [98]	valid_0's auc: 1	valid_0's binary_logloss: 0.000412142
# [99]	valid_0's auc: 1	valid_0's binary_logloss: 0.000405335
# [100]	valid_0's auc: 1	valid_0's binary_logloss: 0.000403681
# [101]	valid_0's auc: 1	valid_0's binary_logloss: 0.000406855
# [102]	valid_0's auc: 1	valid_0's binary_logloss: 0.000408972
# [103]	valid_0's auc: 1	valid_0's binary_logloss: 0.000413087
# [104]	valid_0's auc: 1	valid_0's binary_logloss: 0.000412564
# [105]	valid_0's auc: 1	valid_0's binary_logloss: 0.000409776
# [106]	valid_0's auc: 1	valid_0's binary_logloss: 0.000406284
# [107]	valid_0's auc: 1	valid_0's binary_logloss: 0.000407686
# [108]	valid_0's auc: 1	valid_0's binary_logloss: 0.000406762
# [109]	valid_0's auc: 1	valid_0's binary_logloss: 0.000407594
# [110]	valid_0's auc: 1	valid_0's binary_logloss: 0.000408437
# [111]	valid_0's auc: 1	valid_0's binary_logloss: 0.000416393
# [112]	valid_0's auc: 1	valid_0's binary_logloss: 0.000420834
# [113]	valid_0's auc: 1	valid_0's binary_logloss: 0.000418996
# [114]	valid_0's auc: 1	valid_0's binary_logloss: 0.000419243
# [115]	valid_0's auc: 1	valid_0's binary_logloss: 0.000417911
# [116]	valid_0's auc: 1	valid_0's binary_logloss: 0.000417833
# [117]	valid_0's auc: 1	valid_0's binary_logloss: 0.000421529
# [118]	valid_0's auc: 1	valid_0's binary_logloss: 0.000415552
# [119]	valid_0's auc: 1	valid_0's binary_logloss: 0.00041751
# [120]	valid_0's auc: 1	valid_0's binary_logloss: 0.00041539
# [121]	valid_0's auc: 1	valid_0's binary_logloss: 0.000408904
# [122]	valid_0's auc: 1	valid_0's binary_logloss: 0.000411459
# [123]	valid_0's auc: 1	valid_0's binary_logloss: 0.000414402
# [124]	valid_0's auc: 1	valid_0's binary_logloss: 0.000420147
# [125]	valid_0's auc: 1	valid_0's binary_logloss: 0.00042997
# [126]	valid_0's auc: 1	valid_0's binary_logloss: 0.000431212
# [127]	valid_0's auc: 1	valid_0's binary_logloss: 0.000428637
# [128]	valid_0's auc: 1	valid_0's binary_logloss: 0.00042691
# [129]	valid_0's auc: 1	valid_0's binary_logloss: 0.000426104
# [130]	valid_0's auc: 1	valid_0's binary_logloss: 0.000425137
# [131]	valid_0's auc: 1	valid_0's binary_logloss: 0.000419507
# [132]	valid_0's auc: 1	valid_0's binary_logloss: 0.000410506
# [133]	valid_0's auc: 1	valid_0's binary_logloss: 0.000404143
# [134]	valid_0's auc: 1	valid_0's binary_logloss: 0.000403802
# [135]	valid_0's auc: 1	valid_0's binary_logloss: 0.000399562
# [136]	valid_0's auc: 1	valid_0's binary_logloss: 0.000398347
# [137]	valid_0's auc: 1	valid_0's binary_logloss: 0.000404398
# [138]	valid_0's auc: 1	valid_0's binary_logloss: 0.000400942
# [139]	valid_0's auc: 1	valid_0's binary_logloss: 0.000401173
# [140]	valid_0's auc: 1	valid_0's binary_logloss: 0.000400163
# [141]	valid_0's auc: 1	valid_0's binary_logloss: 0.0004046
# [142]	valid_0's auc: 1	valid_0's binary_logloss: 0.000401529
# [143]	valid_0's auc: 1	valid_0's binary_logloss: 0.000399261
# [144]	valid_0's auc: 1	valid_0's binary_logloss: 0.000402196
# [145]	valid_0's auc: 1	valid_0's binary_logloss: 0.000402159
# [146]	valid_0's auc: 1	valid_0's binary_logloss: 0.00040417
# [147]	valid_0's auc: 1	valid_0's binary_logloss: 0.000402299
# [148]	valid_0's auc: 1	valid_0's binary_logloss: 0.000396396
# [149]	valid_0's auc: 1	valid_0's binary_logloss: 0.00038922
# [150]	valid_0's auc: 1	valid_0's binary_logloss: 0.00038453
# [151]	valid_0's auc: 1	valid_0's binary_logloss: 0.000383929
# [152]	valid_0's auc: 1	valid_0's binary_logloss: 0.00038031
# [153]	valid_0's auc: 1	valid_0's binary_logloss: 0.000376461
# [154]	valid_0's auc: 1	valid_0's binary_logloss: 0.000373024
# [155]	valid_0's auc: 1	valid_0's binary_logloss: 0.000368904
# [156]	valid_0's auc: 1	valid_0's binary_logloss: 0.000367879
# [157]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366759
# [158]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366206
# [159]	valid_0's auc: 1	valid_0's binary_logloss: 0.00036986
# [160]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370599
# [161]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366369
# [162]	valid_0's auc: 1	valid_0's binary_logloss: 0.000367585
# [163]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370554
# [164]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372357
# [165]	valid_0's auc: 1	valid_0's binary_logloss: 0.000374562
# [166]	valid_0's auc: 1	valid_0's binary_logloss: 0.000373625
# [167]	valid_0's auc: 1	valid_0's binary_logloss: 0.000374067
# [168]	valid_0's auc: 1	valid_0's binary_logloss: 0.000376497
# [169]	valid_0's auc: 1	valid_0's binary_logloss: 0.000377662
# [170]	valid_0's auc: 1	valid_0's binary_logloss: 0.000380649
# [171]	valid_0's auc: 1	valid_0's binary_logloss: 0.000379288
# [172]	valid_0's auc: 1	valid_0's binary_logloss: 0.000379138
# [173]	valid_0's auc: 1	valid_0's binary_logloss: 0.000379731
# [174]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003819
# [175]	valid_0's auc: 1	valid_0's binary_logloss: 0.000382239
# [176]	valid_0's auc: 1	valid_0's binary_logloss: 0.000378787
# [177]	valid_0's auc: 1	valid_0's binary_logloss: 0.000374279
# [178]	valid_0's auc: 1	valid_0's binary_logloss: 0.000373015
# [179]	valid_0's auc: 1	valid_0's binary_logloss: 0.00037142
# [180]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372962
# [181]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372557
# [182]	valid_0's auc: 1	valid_0's binary_logloss: 0.00037373
# [183]	valid_0's auc: 1	valid_0's binary_logloss: 0.000374792
# [184]	valid_0's auc: 1	valid_0's binary_logloss: 0.000375393
# [185]	valid_0's auc: 1	valid_0's binary_logloss: 0.000376477
# [186]	valid_0's auc: 1	valid_0's binary_logloss: 0.000375173
# [187]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003738
# [188]	valid_0's auc: 1	valid_0's binary_logloss: 0.000374243
# [189]	valid_0's auc: 1	valid_0's binary_logloss: 0.000373332
# [190]	valid_0's auc: 1	valid_0's binary_logloss: 0.000371365
# [191]	valid_0's auc: 1	valid_0's binary_logloss: 0.00037197
# [192]	valid_0's auc: 1	valid_0's binary_logloss: 0.000373417
# [193]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372912
# [194]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372978
# [195]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370667
# [196]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370883
# [197]	valid_0's auc: 1	valid_0's binary_logloss: 0.000371058
# [198]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369177
# [199]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370368
# [200]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369921
# [201]	valid_0's auc: 1	valid_0's binary_logloss: 0.00037102
# [202]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372245
# [203]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372475
# [204]	valid_0's auc: 1	valid_0's binary_logloss: 0.000372591
# [205]	valid_0's auc: 1	valid_0's binary_logloss: 0.000371492
# [206]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369479
# [207]	valid_0's auc: 1	valid_0's binary_logloss: 0.000368347
# [208]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369419
# [209]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370912
# [210]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370473
# [211]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003704
# [212]	valid_0's auc: 1	valid_0's binary_logloss: 0.000371861
# [213]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369244
# [214]	valid_0's auc: 1	valid_0's binary_logloss: 0.00037195
# [215]	valid_0's auc: 1	valid_0's binary_logloss: 0.00036999
# [216]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369091
# [217]	valid_0's auc: 1	valid_0's binary_logloss: 0.000370468
# [218]	valid_0's auc: 1	valid_0's binary_logloss: 0.000369061
# [219]	valid_0's auc: 1	valid_0's binary_logloss: 0.000367213
# [220]	valid_0's auc: 1	valid_0's binary_logloss: 0.000367321
# [221]	valid_0's auc: 1	valid_0's binary_logloss: 0.000367143
# [222]	valid_0's auc: 1	valid_0's binary_logloss: 0.00036541
# [223]	valid_0's auc: 1	valid_0's binary_logloss: 0.000364999
# [224]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365258
# [225]	valid_0's auc: 1	valid_0's binary_logloss: 0.000364437
# [226]	valid_0's auc: 1	valid_0's binary_logloss: 0.000363999
# [227]	valid_0's auc: 1	valid_0's binary_logloss: 0.000364421
# [228]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365986
# [229]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366434
# [230]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365244
# [231]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365305
# [232]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365411
# [233]	valid_0's auc: 1	valid_0's binary_logloss: 0.000364703
# [234]	valid_0's auc: 1	valid_0's binary_logloss: 0.000364817
# [235]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366222
# [236]	valid_0's auc: 1	valid_0's binary_logloss: 0.000363926
# [237]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365797
# [238]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366593
# [239]	valid_0's auc: 1	valid_0's binary_logloss: 0.000366736
# [240]	valid_0's auc: 1	valid_0's binary_logloss: 0.000367603
# [241]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365774
# [242]	valid_0's auc: 1	valid_0's binary_logloss: 0.000365211
# [243]	valid_0's auc: 1	valid_0's binary_logloss: 0.000364591
# [244]	valid_0's auc: 1	valid_0's binary_logloss: 0.000363172
# [245]	valid_0's auc: 1	valid_0's binary_logloss: 0.000362718
# [246]	valid_0's auc: 1	valid_0's binary_logloss: 0.000363148
# [247]	valid_0's auc: 1	valid_0's binary_logloss: 0.000363516
# [248]	valid_0's auc: 1	valid_0's binary_logloss: 0.000362237
# [249]	valid_0's auc: 1	valid_0's binary_logloss: 0.000361953
# [250]	valid_0's auc: 1	valid_0's binary_logloss: 0.000362692
# [251]	valid_0's auc: 1	valid_0's binary_logloss: 0.000361859
# [252]	valid_0's auc: 1	valid_0's binary_logloss: 0.000360579
# [253]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359166
# [254]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359248
# [255]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359395
# [256]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359218
# [257]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359289
# [258]	valid_0's auc: 1	valid_0's binary_logloss: 0.000360578
# [259]	valid_0's auc: 1	valid_0's binary_logloss: 0.000361548
# [260]	valid_0's auc: 1	valid_0's binary_logloss: 0.000361163
# [261]	valid_0's auc: 1	valid_0's binary_logloss: 0.000360172
# [262]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359532
# [263]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359794
# [264]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359718
# [265]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359399
# [266]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359962
# [267]	valid_0's auc: 1	valid_0's binary_logloss: 0.000360591
# [268]	valid_0's auc: 1	valid_0's binary_logloss: 0.000360116
# [269]	valid_0's auc: 1	valid_0's binary_logloss: 0.000358582
# [270]	valid_0's auc: 1	valid_0's binary_logloss: 0.000358272
# [271]	valid_0's auc: 1	valid_0's binary_logloss: 0.000358295
# [272]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035757
# [273]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035771
# [274]	valid_0's auc: 1	valid_0's binary_logloss: 0.000357969
# [275]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035879
# [276]	valid_0's auc: 1	valid_0's binary_logloss: 0.000358566
# [277]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359301
# [278]	valid_0's auc: 1	valid_0's binary_logloss: 0.000358997
# [279]	valid_0's auc: 1	valid_0's binary_logloss: 0.000358746
# [280]	valid_0's auc: 1	valid_0's binary_logloss: 0.000359051
# [281]	valid_0's auc: 1	valid_0's binary_logloss: 0.000357993
# [282]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035739
# [283]	valid_0's auc: 1	valid_0's binary_logloss: 0.000357842
# [284]	valid_0's auc: 1	valid_0's binary_logloss: 0.000357378
# [285]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035811
# [286]	valid_0's auc: 1	valid_0's binary_logloss: 0.000357981
# [287]	valid_0's auc: 1	valid_0's binary_logloss: 0.000356439
# [288]	valid_0's auc: 1	valid_0's binary_logloss: 0.000355822
# [289]	valid_0's auc: 1	valid_0's binary_logloss: 0.000355553
# [290]	valid_0's auc: 1	valid_0's binary_logloss: 0.000355839
# [291]	valid_0's auc: 1	valid_0's binary_logloss: 0.000355346
# [292]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354941
# [293]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354659
# [294]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354345
# [295]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354247
# [296]	valid_0's auc: 1	valid_0's binary_logloss: 0.000353954
# [297]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354722
# [298]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354637
# [299]	valid_0's auc: 1	valid_0's binary_logloss: 0.000356273
# [300]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354908
# [301]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354458
# [302]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354219
# [303]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354932
# [304]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035478
# [305]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354377
# [306]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035507
# [307]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354885
# [308]	valid_0's auc: 1	valid_0's binary_logloss: 0.000355082
# [309]	valid_0's auc: 1	valid_0's binary_logloss: 0.000354902
# [310]	valid_0's auc: 1	valid_0's binary_logloss: 0.000355114
# [311]	valid_0's auc: 1	valid_0's binary_logloss: 0.000353788
# [312]	valid_0's auc: 1	valid_0's binary_logloss: 0.000353989
# [313]	valid_0's auc: 1	valid_0's binary_logloss: 0.000353488
# [314]	valid_0's auc: 1	valid_0's binary_logloss: 0.000352136
# [315]	valid_0's auc: 1	valid_0's binary_logloss: 0.000352725
# [316]	valid_0's auc: 1	valid_0's binary_logloss: 0.000351437
# [317]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350926
# [318]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350842
# [319]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350978
# [320]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350114
# [321]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350672
# [322]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350771
# [323]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350602
# [324]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350419
# [325]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350216
# [326]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349788
# [327]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034949
# [328]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349708
# [329]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349209
# [330]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348705
# [331]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348784
# [332]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348479
# [333]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348066
# [334]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348378
# [335]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348592
# [336]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034849
# [337]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348206
# [338]	valid_0's auc: 1	valid_0's binary_logloss: 0.000347739
# [339]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348008
# [340]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349618
# [341]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349775
# [342]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349489
# [343]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350173
# [344]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349675
# [345]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349403
# [346]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348961
# [347]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350496
# [348]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350338
# [349]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350167
# [350]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350008
# [351]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349899
# [352]	valid_0's auc: 1	valid_0's binary_logloss: 0.000351158
# [353]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350662
# [354]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350378
# [355]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035018
# [356]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349791
# [357]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350456
# [358]	valid_0's auc: 1	valid_0's binary_logloss: 0.00035029
# [359]	valid_0's auc: 1	valid_0's binary_logloss: 0.000350126
# [360]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349947
# [361]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034879
# [362]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348587
# [363]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348204
# [364]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348724
# [365]	valid_0's auc: 1	valid_0's binary_logloss: 0.000349016
# [366]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348092
# [367]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348298
# [368]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348929
# [369]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348763
# [370]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348514
# [371]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034832
# [372]	valid_0's auc: 1	valid_0's binary_logloss: 0.000347092
# [373]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003477
# [374]	valid_0's auc: 1	valid_0's binary_logloss: 0.000347214
# [375]	valid_0's auc: 1	valid_0's binary_logloss: 0.000348249
# [376]	valid_0's auc: 1	valid_0's binary_logloss: 0.000347198
# [377]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346991
# [378]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346846
# [379]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346608
# [380]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346683
# [381]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346491
# [382]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346275
# [383]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346858
# [384]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346389
# [385]	valid_0's auc: 1	valid_0's binary_logloss: 0.000346109
# [386]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345995
# [387]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344931
# [388]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344736
# [389]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343883
# [390]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343697
# [391]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344264
# [392]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344505
# [393]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344527
# [394]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345507
# [395]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344473
# [396]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345283
# [397]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345444
# [398]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345291
# [399]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344164
# [400]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344295
# [401]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344536
# [402]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034508
# [403]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345341
# [404]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345177
# [405]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345312
# [406]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344847
# [407]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344658
# [408]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344543
# [409]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344323
# [410]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343515
# [411]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343442
# [412]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343698
# [413]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343913
# [414]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344628
# [415]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344128
# [416]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344279
# [417]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344933
# [418]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344873
# [419]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345336
# [420]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344545
# [421]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344461
# [422]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344231
# [423]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034402
# [424]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343841
# [425]	valid_0's auc: 1	valid_0's binary_logloss: 0.000345026
# [426]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034472
# [427]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344336
# [428]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344478
# [429]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344162
# [430]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343984
# [431]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344567
# [432]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344291
# [433]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344535
# [434]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003446
# [435]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344376
# [436]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344191
# [437]	valid_0's auc: 1	valid_0's binary_logloss: 0.000344043
# [438]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343018
# [439]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343223
# [440]	valid_0's auc: 1	valid_0's binary_logloss: 0.000342958
# [441]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343756
# [442]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343323
# [443]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343396
# [444]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343184
# [445]	valid_0's auc: 1	valid_0's binary_logloss: 0.000342253
# [446]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343012
# [447]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343589
# [448]	valid_0's auc: 1	valid_0's binary_logloss: 0.000343358
# [449]	valid_0's auc: 1	valid_0's binary_logloss: 0.000342336
# [450]	valid_0's auc: 1	valid_0's binary_logloss: 0.000342594
# [451]	valid_0's auc: 1	valid_0's binary_logloss: 0.000342432
# [452]	valid_0's auc: 1	valid_0's binary_logloss: 0.00034183
# [453]	valid_0's auc: 1	valid_0's binary_logloss: 0.000341576
# [454]	valid_0's auc: 1	valid_0's binary_logloss: 0.000341486
# [455]	valid_0's auc: 1	valid_0's binary_logloss: 0.000341325
# [456]	valid_0's auc: 1	valid_0's binary_logloss: 0.000341114
# [457]	valid_0's auc: 1	valid_0's binary_logloss: 0.000340956
# [458]	valid_0's auc: 1	valid_0's binary_logloss: 0.000341083
# [459]	valid_0's auc: 1	valid_0's binary_logloss: 0.000340631
# [460]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339809
# [461]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339647
# [462]	valid_0's auc: 1	valid_0's binary_logloss: 0.000338911
# [463]	valid_0's auc: 1	valid_0's binary_logloss: 0.000338659
# [464]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339426
# [465]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339857
# [466]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339649
# [467]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339365
# [468]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339203
# [469]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339402
# [470]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339235
# [471]	valid_0's auc: 1	valid_0's binary_logloss: 0.000338566
# [472]	valid_0's auc: 1	valid_0's binary_logloss: 0.000338318
# [473]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339044
# [474]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339293
# [475]	valid_0's auc: 1	valid_0's binary_logloss: 0.000339092
# [476]	valid_0's auc: 1	valid_0's binary_logloss: 0.000338183
# [477]	valid_0's auc: 1	valid_0's binary_logloss: 0.000338027
# [478]	valid_0's auc: 1	valid_0's binary_logloss: 0.00033774
# [479]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336769
# [480]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336458
# [481]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336658
# [482]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336494
# [483]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336647
# [484]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336703
# [485]	valid_0's auc: 1	valid_0's binary_logloss: 0.000336592
# [486]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335995
# [487]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335129
# [488]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335131
# [489]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334402
# [490]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335099
# [491]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335342
# [492]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335055
# [493]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335172
# [494]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335564
# [495]	valid_0's auc: 1	valid_0's binary_logloss: 0.000335407
# [496]	valid_0's auc: 1	valid_0's binary_logloss: 0.00033521
# [497]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334998
# [498]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334105
# [499]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334159
# [500]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334019
# [501]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334303
# [502]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334498
# [503]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334391
# [504]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334096
# [505]	valid_0's auc: 1	valid_0's binary_logloss: 0.000334288
# [506]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333982
# [507]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333348
# [508]	valid_0's auc: 1	valid_0's binary_logloss: 0.00033264
# [509]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333256
# [510]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333403
# [511]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333887
# [512]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333709
# [513]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333408
# [514]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333226
# [515]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332981
# [516]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332627
# [517]	valid_0's auc: 1	valid_0's binary_logloss: 0.00033206
# [518]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332769
# [519]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333192
# [520]	valid_0's auc: 1	valid_0's binary_logloss: 0.000333054
# [521]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332757
# [522]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332571
# [523]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332233
# [524]	valid_0's auc: 1	valid_0's binary_logloss: 0.000331707
# [525]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332135
# [526]	valid_0's auc: 1	valid_0's binary_logloss: 0.000331989
# [527]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332392
# [528]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332253
# [529]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332534
# [530]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332229
# [531]	valid_0's auc: 1	valid_0's binary_logloss: 0.000332043
# [532]	valid_0's auc: 1	valid_0's binary_logloss: 0.000331727
# [533]	valid_0's auc: 1	valid_0's binary_logloss: 0.000331152
# [534]	valid_0's auc: 1	valid_0's binary_logloss: 0.000331396
# [535]	valid_0's auc: 1	valid_0's binary_logloss: 0.000330842
# [536]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329929
# [537]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032909
# [538]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329288
# [539]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329966
# [540]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329203
# [541]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329548
# [542]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329339
# [543]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329781
# [544]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329628
# [545]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329078
# [546]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329315
# [547]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329703
# [548]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329909
# [549]	valid_0's auc: 1	valid_0's binary_logloss: 0.000330299
# [550]	valid_0's auc: 1	valid_0's binary_logloss: 0.000330101
# [551]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329954
# [552]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329734
# [553]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329932
# [554]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032919
# [555]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329484
# [556]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032931
# [557]	valid_0's auc: 1	valid_0's binary_logloss: 0.000328945
# [558]	valid_0's auc: 1	valid_0's binary_logloss: 0.000328738
# [559]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329105
# [560]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329401
# [561]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329665
# [562]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329547
# [563]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329248
# [564]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329659
# [565]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329508
# [566]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329344
# [567]	valid_0's auc: 1	valid_0's binary_logloss: 0.000329021
# [568]	valid_0's auc: 1	valid_0's binary_logloss: 0.000328761
# [569]	valid_0's auc: 1	valid_0's binary_logloss: 0.000328235
# [570]	valid_0's auc: 1	valid_0's binary_logloss: 0.000328043
# [571]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032803
# [572]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327167
# [573]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326444
# [574]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326715
# [575]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326911
# [576]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327196
# [577]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327152
# [578]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326868
# [579]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326624
# [580]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327041
# [581]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327304
# [582]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327119
# [583]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327475
# [584]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327805
# [585]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327793
# [586]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327754
# [587]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032812
# [588]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327893
# [589]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327854
# [590]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327598
# [591]	valid_0's auc: 1	valid_0's binary_logloss: 0.000328017
# [592]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327846
# [593]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327591
# [594]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327436
# [595]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327165
# [596]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327014
# [597]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326834
# [598]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326654
# [599]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327044
# [600]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327349
# [601]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327202
# [602]	valid_0's auc: 1	valid_0's binary_logloss: 0.000327168
# [603]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326946
# [604]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326687
# [605]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326107
# [606]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325942
# [607]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325931
# [608]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326087
# [609]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325898
# [610]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325724
# [611]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326106
# [612]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326418
# [613]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326407
# [614]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326709
# [615]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326504
# [616]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326268
# [617]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325883
# [618]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325873
# [619]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325201
# [620]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325381
# [621]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325214
# [622]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325581
# [623]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325417
# [624]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325659
# [625]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325494
# [626]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325174
# [627]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325338
# [628]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325384
# [629]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032535
# [630]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325308
# [631]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325461
# [632]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325504
# [633]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325361
# [634]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325578
# [635]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325545
# [636]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325735
# [637]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032559
# [638]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325784
# [639]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325427
# [640]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325618
# [641]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325801
# [642]	valid_0's auc: 1	valid_0's binary_logloss: 0.000326205
# [643]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325976
# [644]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325619
# [645]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325611
# [646]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325385
# [647]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325125
# [648]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325028
# [649]	valid_0's auc: 1	valid_0's binary_logloss: 0.000324985
# [650]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325138
# [651]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032518
# [652]	valid_0's auc: 1	valid_0's binary_logloss: 0.000325038
# [653]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032487
# [654]	valid_0's auc: 1	valid_0's binary_logloss: 0.000324694
# [655]	valid_0's auc: 1	valid_0's binary_logloss: 0.000324685
# [656]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032488
# [657]	valid_0's auc: 1	valid_0's binary_logloss: 0.000324919
# [658]	valid_0's auc: 1	valid_0's binary_logloss: 0.000324565
# [659]	valid_0's auc: 1	valid_0's binary_logloss: 0.000324556
# [660]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323758
# [661]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323798
# [662]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323468
# [663]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032363
# [664]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323622
# [665]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323456
# [666]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322742
# [667]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322602
# [668]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322748
# [669]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322792
# [670]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322629
# [671]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322795
# [672]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322989
# [673]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323029
# [674]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322961
# [675]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323186
# [676]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323347
# [677]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323278
# [678]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323129
# [679]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323168
# [680]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323564
# [681]	valid_0's auc: 1	valid_0's binary_logloss: 0.000323415
# [682]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032326
# [683]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322956
# [684]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322999
# [685]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322732
# [686]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322922
# [687]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322963
# [688]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322892
# [689]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322791
# [690]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322718
# [691]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322391
# [692]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322108
# [693]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322154
# [694]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322146
# [695]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322343
# [696]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322387
# [697]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322548
# [698]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322477
# [699]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322208
# [700]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322254
# [701]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322247
# [702]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322135
# [703]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322545
# [704]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322587
# [705]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322967
# [706]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322932
# [707]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322777
# [708]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322619
# [709]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322426
# [710]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032242
# [711]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321801
# [712]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321831
# [713]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032152
# [714]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321514
# [715]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032141
# [716]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321605
# [717]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321339
# [718]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321382
# [719]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321398
# [720]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321439
# [721]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321198
# [722]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321241
# [723]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320762
# [724]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320755
# [725]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320799
# [726]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320838
# [727]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320775
# [728]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320614
# [729]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320542
# [730]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320724
# [731]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320692
# [732]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320687
# [733]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320431
# [734]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320474
# [735]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320406
# [736]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320375
# [737]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320021
# [738]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320015
# [739]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032001
# [740]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032007
# [741]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320101
# [742]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319955
# [743]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319995
# [744]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320011
# [745]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319867
# [746]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319884
# [747]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319999
# [748]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320044
# [749]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319978
# [750]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319947
# [751]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319942
# [752]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319885
# [753]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319626
# [754]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319585
# [755]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031998
# [756]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319944
# [757]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031979
# [758]	valid_0's auc: 1	valid_0's binary_logloss: 0.000319616
# [759]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320006
# [760]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320327
# [761]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320713
# [762]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321081
# [763]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321342
# [764]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321306
# [765]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321656
# [766]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321619
# [767]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321343
# [768]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321229
# [769]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321576
# [770]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321782
# [771]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321746
# [772]	valid_0's auc: 1	valid_0's binary_logloss: 0.000322078
# [773]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321951
# [774]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321911
# [775]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321956
# [776]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321913
# [777]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032188
# [778]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032161
# [779]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321574
# [780]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321332
# [781]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003213
# [782]	valid_0's auc: 1	valid_0's binary_logloss: 0.000321145
# [783]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320994
# [784]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320786
# [785]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320606
# [786]	valid_0's auc: 1	valid_0's binary_logloss: 0.00032056
# [787]	valid_0's auc: 1	valid_0's binary_logloss: 0.000320557
# ...
# [2743]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314902
# [2744]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314807
# [2745]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314931
# [2746]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314916
# [2747]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314977
# [2748]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314941
# [2749]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314945
# [2750]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031492
# [2751]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315063
# [2752]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314865
# [2753]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031506
# [2754]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314904
# [2755]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315098
# [2756]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314901
# [2757]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314991
# [2758]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314905
# [2759]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315069
# [2760]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314993
# [2761]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314931
# [2762]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314992
# [2763]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315017
# [2764]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315028
# [2765]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315007
# [2766]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314969
# [2767]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315069
# [2768]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314874
# [2769]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314999
# [2770]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314936
# [2771]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314969
# [2772]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314869
# [2773]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314959
# [2774]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314835
# [2775]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314963
# [2776]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315126
# [2777]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315051
# [2778]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314975
# [2779]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315035
# [2780]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314935
# [2781]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314965
# [2782]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314981
# [2783]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031496
# [2784]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314977
# [2785]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315002
# [2786]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314964
# [2787]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315044
# [2788]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315077
# [2789]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315051
# [2790]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314926
# [2791]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315051
# [2792]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314927
# [2793]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031505
# [2794]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314927
# [2795]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315049
# [2796]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315032
# [2797]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315047
# [2798]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031503
# [2799]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315044
# [2800]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315069
# [2801]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315104
# [2802]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315016
# [2803]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315022
# [2804]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031491
# [2805]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315015
# [2806]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314918
# [2807]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315008
# [2808]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314983
# [2809]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315017
# [2810]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314906
# [2811]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314912
# [2812]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314887
# [2813]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314921
# [2814]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314921
# [2815]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314924
# [2816]	valid_0's auc: 1	valid_0's binary_logloss: 0.0003149
# [2817]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315008
# [2818]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314985
# [2819]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315074
# [2820]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314877
# [2821]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315073
# [2822]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314878
# [2823]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315023
# [2824]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315004
# [2825]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315015
# [2826]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031504
# [2827]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315051
# [2828]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031503
# [2829]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314992
# [2830]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314975
# [2831]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315086
# [2832]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031499
# [2833]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315094
# [2834]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314979
# [2835]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315082
# [2836]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314995
# [2837]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315029
# [2838]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315054
# [2839]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315016
# [2840]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315182
# [2841]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315108
# [2842]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315086
# [2843]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315188
# [2844]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031508
# [2845]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315017
# [2846]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314891
# [2847]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314891
# [2848]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314873
# [2849]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315036
# [2850]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314962
# [2851]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315081
# [2852]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314956
# [2853]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315014
# [2854]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314951
# [2855]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314977
# [2856]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314993
# [2857]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314973
# [2858]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031499
# [2859]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314969
# [2860]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314985
# [2861]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315011
# [2862]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315021
# [2863]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315002
# [2864]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315016
# [2865]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314998
# [2866]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315012
# [2867]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314995
# [2868]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315102
# [2869]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314993
# [2870]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315112
# [2871]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314987
# [2872]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031485
# [2873]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315014
# [2874]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315115
# [2875]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315258
# [2876]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315105
# [2877]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315299
# [2878]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315106
# [2879]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031511
# [2880]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315109
# [2881]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315113
# [2882]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315112
# [2883]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315116
# [2884]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315007
# [2885]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315099
# [2886]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315099
# [2887]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315196
# [2888]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315056
# [2889]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315175
# [2890]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315157
# [2891]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315174
# [2892]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315157
# [2893]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315173
# [2894]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315064
# [2895]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031517
# [2896]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315075
# [2897]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315198
# [2898]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315007
# [2899]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315199
# [2900]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315045
# [2901]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315049
# [2902]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315013
# [2903]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315155
# [2904]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315169
# [2905]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315151
# [2906]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315166
# [2907]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315052
# [2908]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315142
# [2909]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315056
# [2910]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315062
# [2911]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315065
# [2912]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315256
# [2913]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315238
# [2914]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315214
# [2915]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315246
# [2916]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315169
# [2917]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315169
# [2918]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315186
# [2919]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315033
# [2920]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315156
# [2921]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315058
# [2922]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315149
# [2923]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315065
# [2924]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315172
# [2925]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315197
# [2926]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315208
# [2927]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315187
# [2928]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315204
# [2929]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315229
# [2930]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315191
# [2931]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315174
# [2932]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031519
# [2933]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315215
# [2934]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315226
# [2935]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315206
# [2936]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315221
# [2937]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315203
# [2938]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031531
# [2939]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315215
# [2940]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315222
# [2941]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315137
# [2942]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315241
# [2943]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315135
# [2944]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315242
# [2945]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315221
# [2946]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315255
# [2947]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315167
# [2948]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315129
# [2949]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315112
# [2950]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315126
# [2951]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315204
# [2952]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315229
# [2953]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315245
# [2954]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315053
# [2955]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315078
# [2956]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315112
# [2957]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315087
# [2958]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315209
# [2959]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315115
# [2960]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315207
# [2961]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315083
# [2962]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315021
# [2963]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031508
# [2964]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315019
# [2965]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315077
# [2966]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314989
# [2967]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315023
# [2968]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314924
# [2969]	valid_0's auc: 1	valid_0's binary_logloss: 0.000315112
# [2970]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314918
# [2971]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314922
# [2972]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314897
# [2973]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314903
# [2974]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314903
# [2975]	valid_0's auc: 1	valid_0's binary_logloss: 0.00031489
# [2976]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314894
# [2977]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314869
# [2978]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314869
# [2979]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314869
# [2980]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314988
# [2981]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314893
# [2982]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314996
# [2983]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314887
# [2984]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314976
# [2985]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314863
# [2986]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314965
# [2987]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314879
# [2988]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314912
# [2989]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314887
# [2990]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314881
# [2991]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314906
# [2992]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314917
# [2993]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314942
# [2994]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314976
# [2995]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314939
# [2996]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314921
# [2997]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314861
# [2998]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314919
# [2999]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314859
# [3000]	valid_0's auc: 1	valid_0's binary_logloss: 0.000314891
